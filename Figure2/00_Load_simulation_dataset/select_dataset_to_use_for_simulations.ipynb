# %% [markdown]
# # Aim of the notebook
#
# Importing a dataset to use for simulated CNVs to test technical limitations

# %% [markdown]
# Import packages

# %%
import cellxgene_census
import seaborn as sns
import pandas as pd
import numpy as np
import scanpy as sc
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Extract cell metadata from census [2024-07-01]

# %%
with cellxgene_census.open_soma() as census:
    # Reads SOMADataFrame as a slice
    cell_metadata_master = census["census_data"]["homo_sapiens"].obs.read(
        value_filter = "disease == 'normal'",
        column_names = ["assay", "cell_type", "tissue", "tissue_general", "donor_id", "disease","dataset_id"])
    # Concatenates results to pyarrow.Table
    cell_metadata_master = cell_metadata_master.concat()
    # Converts to pandas.DataFrame
    cell_metadata_master = cell_metadata_master.to_pandas()
# Out:
# The "stable" release is currently 2024-07-01. Specify 'census_version="2024-07-01"' in future calls to open_soma() to ensure data consistency.

# %%
# Filter for specific criteria
cell_metadata_filtered = cell_metadata_master[
    (cell_metadata_master['assay'] == "10x 3' v3") &
    (cell_metadata_master['disease'] == 'normal')
]

# %%
set(cell_metadata_filtered.cell_type.unique())
# Out:
# {'A2 amacrine cell',
#  'B cell',
#  'BEST4+ intestinal epithelial cell, human',
#  'Bergmann glial cell',
#  'CD14-low, CD16-positive monocyte',
#  'CD14-positive monocyte',
#  'CD14-positive, CD16-positive monocyte',
#  'CD141-positive myeloid dendritic cell',
#  'CD16-negative, CD56-bright natural killer cell, human',
#  'CD16-positive, CD56-dim natural killer cell, human',
#  'CD1c-positive myeloid dendritic cell',
#  'CD4-positive helper T cell',
#  'CD4-positive, alpha-beta T cell',
#  'CD4-positive, alpha-beta cytotoxic T cell',
#  'CD4-positive, alpha-beta memory T cell',
#  'CD8-alpha-alpha-positive, alpha-beta intraepithelial T cell',
#  'CD8-positive, alpha-beta T cell',
#  'CD8-positive, alpha-beta cytokine secreting effector T cell',
#  'CD8-positive, alpha-beta cytotoxic T cell',
#  'CD8-positive, alpha-beta memory T cell',
#  'CD8-positive, alpha-beta memory T cell, CD45RO-positive',
#  'DN1 thymic pro-T cell',
#  'DN3 thymocyte',
#  'DN4 thymocyte',
#  'GABAergic amacrine cell',
#  'GABAergic interneuron',
#  'GABAergic neuron',
#  'H1 horizontal cell',
#  'H2 horizontal cell',
#  'Hofbauer cell',
#  'IgA plasma cell',
#  'IgG memory B cell',
#  'IgG plasma cell',
#  'IgG-negative class switched memory B cell',
#  'Kupffer cell',
#  'L2/3 intratelencephalic projecting glutamatergic neuron',
#  'L2/3-6 intratelencephalic projecting glutamatergic neuron',
#  'L5 extratelencephalic projecting glutamatergic cortical neuron',
#  'L5/6 near-projecting glutamatergic neuron of the primary motor cortex',
#  'L6 corticothalamic-projecting glutamatergic cortical neuron',
#  'L6 intratelencephalic projecting glutamatergic neuron of the primary motor cortex',
#  'L6b glutamatergic cortical neuron',
#  'Langerhans cell',
#  'Merkel cell',
#  'Mueller cell',
#  'NKp46-positive innate lymphoid cell, human',
#  'OFF retinal ganglion cell',
#  'OFF-bipolar cell',
#  'OFFx cell',
#  'ON retinal ganglion cell',
#  'ON-bipolar cell',
#  'ON-blue cone bipolar cell',
#  'P/D1 enteroendocrine cell',
#  'PP cell',
#  'Purkinje cell',
#  'S cone cell',
#  'Schwann cell',
#  'T cell',
#  'T follicular helper cell',
#  'T-helper 17 cell',
#  'Tc1 cell',
#  'acinar cell',
#  'acinar cell of salivary gland',
#  'activated CD4-positive, alpha-beta T cell',
#  'activated CD4-positive, alpha-beta T cell, human',
#  'activated CD8-positive, alpha-beta T cell',
#  'activated CD8-positive, alpha-beta T cell, human',
#  'adipocyte',
#  'adipocyte of breast',
#  'adipocyte of epicardial fat of left ventricle',
#  'adventitial cell',
#  'airway submucosal gland duct basal cell',
#  'alpha-beta T cell',
#  'alternatively activated macrophage',
#  'alveolar macrophage',
#  'alveolar type 1 fibroblast cell',
#  'alveolar type 2 fibroblast cell',
#  'amacrine cell',
#  'anterior lens cell',
#  'astrocyte',
#  'astrocyte of the cerebral cortex',
#  'basal cell',
#  'basal cell of epidermis',
#  'basal cell of prostate epithelium',
#  'basophil',
#  'bladder urothelial cell',
#  'blood cell',
#  'blood vessel endothelial cell',
#  'blood vessel smooth muscle cell',
#  'brain vascular cell',
#  'bronchial goblet cell',
#  'bronchial smooth muscle cell',
#  'bronchus fibroblast of lung',
#  'brush cell',
#  'brush cell of trachebronchial tree',
#  'capillary endothelial cell',
#  'cardiac endothelial cell',
#  'cardiac mesenchymal cell',
#  'cardiac muscle cell',
#  'cardiac muscle myoblast',
#  'cardiac neuron',
#  'caudal ganglionic eminence derived GABAergic cortical interneuron',
#  'cell of skeletal muscle',
#  'central memory CD4-positive, alpha-beta T cell',
#  'central memory CD8-positive, alpha-beta T cell',
#  'central nervous system macrophage',
#  'centrilobular region hepatocyte',
#  'cerebellar granule cell',
#  'cerebellar granule cell precursor',
#  'cerebral cortex endothelial cell',
#  'chandelier cell',
#  'chandelier pvalb GABAergic cortical interneuron',
#  'cholangiocyte',
#  'chondrocyte',
#  'choroid plexus epithelial cell',
#  'ciliary muscle cell',
#  'ciliated cell',
#  'ciliated columnar cell of tracheobronchial tree',
#  'ciliated epithelial cell',
#  'class switched memory B cell',
#  'classical monocyte',
#  'club cell',
#  'colon goblet cell',
#  'common dendritic progenitor',
#  'common lymphoid progenitor',
#  'common myeloid progenitor',
#  'cone retinal bipolar cell',
#  'conjunctival epithelial cell',
#  'connective tissue cell',
#  'conventional dendritic cell',
#  'corneal endothelial cell',
#  'corneal epithelial cell',
#  'cortical interneuron',
#  'cortical thymic epithelial cell',
#  'corticothalamic-projecting glutamatergic cortical neuron',
#  'cytotoxic T cell',
#  'decidual natural killer cell, human',
#  'dendritic cell',
#  'dendritic cell, human',
#  'deuterosomal cell',
#  'differentiation-committed oligodendrocyte precursor',
#  'diffuse bipolar 1 cell',
#  'diffuse bipolar 2 cell',
#  'diffuse bipolar 3a cell',
#  'diffuse bipolar 3b cell',
#  'diffuse bipolar 4 cell',
#  'diffuse bipolar 6 cell',
#  'direct pathway medium spiny neuron',
#  'dopaminergic neuron',
#  'double negative thymocyte',
#  'double-positive, alpha-beta thymocyte',
#  'duct epithelial cell',
#  'duodenum glandular cell',
#  'early T lineage precursor',
#  'early lymphoid progenitor',
#  'effector CD4-positive, alpha-beta T cell',
#  'effector CD8-positive, alpha-beta T cell',
#  'effector memory CD4-positive, alpha-beta T cell',
#  'effector memory CD8-positive, alpha-beta T cell',
#  'effector memory CD8-positive, alpha-beta T cell, terminally differentiated',
#  'elicited macrophage',
#  'embryonic fibroblast',
#  'endocardial cell',
#  'endocrine cell',
#  'endothelial cell',
#  'endothelial cell of artery',
#  'endothelial cell of hepatic sinusoid',
#  'endothelial cell of lymphatic vessel',
#  'endothelial cell of pericentral hepatic sinusoid',
#  'endothelial cell of periportal hepatic sinusoid',
#  'endothelial cell of placenta',
#  'endothelial cell of sinusoid',
#  'endothelial cell of uterus',
#  'endothelial cell of vascular tree',
#  'endothelial cell of venule',
#  'endothelial tip cell',
#  'enteric smooth muscle cell',
#  'enterocyte',
#  'enterocyte of epithelium of large intestine',
#  'enterocyte of epithelium of small intestine',
#  'enteroendocrine cell',
#  'enteroendocrine cell of colon',
#  'enteroendocrine cell of small intestine',
#  'enucleate erythrocyte',
#  'eosinophil',
#  'ependymal cell',
#  'epicardial adipocyte',
#  'epithelial cell',
#  'epithelial cell of alveolus of lung',
#  'epithelial cell of esophagus',
#  'epithelial cell of lacrimal sac',
#  'epithelial cell of lower respiratory tract',
#  'epithelial cell of lung',
#  'epithelial cell of proximal tubule',
#  'epithelial cell of small intestine',
#  'epithelial cell of thymus',
#  'epithelial cell of uterus',
#  'erythroblast',
#  'erythrocyte',
#  'erythroid lineage cell',
#  'erythroid progenitor cell',
#  'extravillous trophoblast',
#  'eye photoreceptor cell',
#  'fast muscle cell',
#  'fetal cardiomyocyte',
#  'fibro/adipogenic progenitor cell',
#  'fibroblast',
#  'fibroblast of breast',
#  'fibroblast of cardiac tissue',
#  'fibroblast of lung',
#  'fibroblast of mammary gland',
#  'fibrocyte',
#  'flat midget bipolar cell',
#  'forebrain neuroblast',
#  'foveolar cell of stomach',
#  'fraction A pre-pro B cell',
#  'gamma-delta T cell',
#  'germinal center B cell',
#  'giant bipolar cell',
#  'glandular cell of esophagus',
#  'glandular epithelial cell',
#  'glial cell',
#  'glioblast',
#  'glutamatergic neuron',
#  'glycinergic amacrine cell',
#  'goblet cell',
#  'granular cell of epidermis',
#  'granulocyte',
#  'granulocyte monocyte progenitor cell',
#  'group 3 innate lymphoid cell',
#  'group 3 innate lymphoid cell, human',
#  'gut absorptive cell',
#  'gut endothelial cell',
#  'hair follicular keratinocyte',
#  'helper T cell',
#  'hematopoietic cell',
#  'hematopoietic multipotent progenitor cell',
#  'hematopoietic stem cell',
#  'hepatic pit cell',
#  'hepatic stellate cell',
#  'hepatocyte',
#  'immature B cell',
#  'immature NK T cell',
#  'immature astrocyte',
#  'immature innate lymphoid cell',
#  'immature natural killer cell',
#  'indirect pathway medium spiny neuron',
#  'inflammatory macrophage',
#  'inhibitory interneuron',
#  'inhibitory motor neuron',
#  'innate lymphoid cell',
#  'intermediate monocyte',
#  'interneuron',
#  'interstitial cell of Cajal',
#  'intestinal crypt stem cell',
#  'intestinal crypt stem cell of colon',
#  'intestinal crypt stem cell of large intestine',
#  'intestinal crypt stem cell of small intestine',
#  'intestinal enteroendocrine cell',
#  'intestinal epithelial cell',
#  'intestinal tuft cell',
#  'intestine goblet cell',
#  'intraepithelial lymphocyte',
#  'intrahepatic cholangiocyte',
#  'invaginating midget bipolar cell',
#  'ionocyte',
#  'keratinocyte',
#  'keratocyte',
#  'kidney collecting duct intercalated cell',
#  'kidney collecting duct principal cell',
#  'kidney connecting tubule epithelial cell',
#  'kidney distal convoluted tubule epithelial cell',
#  'kidney epithelial cell',
#  'kidney interstitial alternatively activated macrophage',
#  'kidney interstitial cell',
#  'kidney interstitial fibroblast',
#  'kidney loop of Henle thick ascending limb epithelial cell',
#  'kidney loop of Henle thin ascending limb epithelial cell',
#  'kidney loop of Henle thin descending limb epithelial cell',
#  'lamp5 GABAergic cortical interneuron',
#  'large intestine goblet cell',
#  'lens epithelial cell',
#  'lens fiber cell',
#  'leptomeningeal cell',
#  'leukocyte',
#  'liver dendritic cell',
#  'luminal adaptive secretory precursor cell of mammary gland',
#  'luminal cell of prostate epithelium',
#  'luminal epithelial cell of mammary gland',
#  'luminal hormone-sensing cell of mammary gland',
#  'lung ciliated cell',
#  'lung goblet cell',
#  'lung interstitial macrophage',
#  'lung macrophage',
#  'lung microvascular endothelial cell',
#  'lung neuroendocrine cell',
#  'lung perichondrial fibroblast',
#  'lung pericyte',
#  'lung resident memory CD4-positive, alpha-beta T cell',
#  'lung resident memory CD8-positive, alpha-beta T cell',
#  'lung secretory cell',
#  'lymphocyte',
#  'lymphoid lineage restricted progenitor cell',
#  'macroglial cell',
#  'macrophage',
#  'mammary gland epithelial cell',
#  'mast cell',
#  'mature B cell',
#  'mature NK T cell',
#  'mature conventional dendritic cell',
#  'medium spiny neuron',
#  'medullary thymic epithelial cell',
#  'megakaryocyte',
#  'megakaryocyte-erythroid progenitor cell',
#  'melanocyte',
#  'melanocyte of skin',
#  'memory B cell',
#  'memory T cell',
#  'memory regulatory T cell',
#  'meningeal macrophage',
#  'mesangial cell',
#  'mesenchymal cell',
#  'mesenchymal stem cell',
#  'mesodermal cell',
#  'mesothelial cell',
#  'mesothelial cell of epicardium',
#  'mesothelial fibroblast',
#  'metallothionein-positive alveolar macrophage',
#  'microfold cell of epithelium of small intestine',
#  'microglial cell',
#  'midget ganglion cell of retina',
#  'midzonal region hepatocyte',
#  'monocyte',
#  'mononuclear phagocyte',
#  'motor neuron',
#  'mucosal invariant T cell',
#  'mucous neck cell',
#  'mucus secreting cell',
#  'multi-ciliated epithelial cell',
#  'mural cell',
#  'muscle cell',
#  'myelinating Schwann cell',
#  'myeloid cell',
#  'myeloid dendritic cell',
#  'myeloid dendritic cell, human',
#  'myeloid leukocyte',
#  'myeloid lineage restricted progenitor cell',
#  'myoblast',
#  'myoepithelial cell',
#  'myoepithelial cell of mammary gland',
#  'myofibroblast cell',
#  'myometrial cell',
#  'naive B cell',
#  'naive T cell',
#  'naive regulatory T cell',
#  'naive thymus-derived CD4-positive, alpha-beta T cell',
#  'naive thymus-derived CD8-positive, alpha-beta T cell',
#  'nasal mucosa goblet cell',
#  'natural T-regulatory cell',
#  'natural killer cell',
#  'near-projecting glutamatergic cortical neuron',
#  'neural cell',
#  'neural crest cell',
#  'neural progenitor cell',
#  'neuroblast (sensu Vertebrata)',
#  'neuroendocrine cell',
#  'neuron',
#  'neuron associated cell',
#  'neuronal receptor cell',
#  'neutrophil',
#  'non-classical monocyte',
#  'non-myelinating Schwann cell',
#  'non-pigmented ciliary epithelial cell',
#  'noradrenergic cell',
#  'oligodendrocyte',
#  'oligodendrocyte precursor cell',
#  'osteoclast',
#  'pancreatic A cell',
#  'pancreatic D cell',
#  'pancreatic PP cell',
#  'pancreatic acinar cell',
#  'pancreatic ductal cell',
#  'pancreatic epsilon cell',
#  'pancreatic stellate cell',
#  'paneth cell',
#  'paneth cell of colon',
#  'paneth cell of epithelium of small intestine',
#  'papillary tips cell',
#  'parasol ganglion cell of retina',
#  'parietal cell',
#  'parietal epithelial cell',
#  'peptic cell',
#  'pericyte',
#  'peripheral nervous system neuron',
#  'periportal region hepatocyte',
#  'perivascular cell',
#  'pigmented ciliary epithelial cell',
#  'pigmented epithelial cell',
#  'placental villous trophoblast',
#  'plasma cell',
#  'plasmablast',
#  'plasmacytoid dendritic cell',
#  'plasmacytoid dendritic cell, human',
#  'platelet',
#  'podocyte',
#  'preadipocyte',
#  'precursor B cell',
#  'primitive red blood cell',
#  'pro-B cell',
#  'proerythroblast',
#  'progenitor cell',
#  'promonocyte',
#  'promyelocyte',
#  'pulmonary artery endothelial cell',
#  'pulmonary ionocyte',
#  'pvalb GABAergic cortical interneuron',
#  'radial glial cell',
#  'regular atrial cardiac myocyte',
#  'regular ventricular cardiac myocyte',
#  'regulatory T cell',
#  'renal alpha-intercalated cell',
#  'renal beta-intercalated cell',
#  'renal interstitial pericyte',
#  'renal principal cell',
#  'respiratory basal cell',
#  'respiratory goblet cell',
#  'respiratory hillock cell',
#  'respiratory suprabasal cell',
#  'retina horizontal cell',
#  'retinal astrocyte',
#  'retinal bipolar neuron',
#  'retinal blood vessel endothelial cell',
#  'retinal cone cell',
#  'retinal ganglion cell',
#  'retinal pigment epithelial cell',
#  'retinal rod cell',
#  'rod bipolar cell',
#  'salivary gland cell',
#  'sebum secreting cell',
#  'secondary lens fiber',
#  'secretory cell',
#  'sensory neuron',
#  'serous cell of epithelium of bronchus',
#  'serous cell of epithelium of trachea',
#  'serous secreting cell',
#  'serous secreting cell of bronchus submucosal gland',
#  'skeletal muscle fiber',
#  'skeletal muscle satellite cell',
#  'skeletal muscle satellite stem cell',
#  'skin fibroblast',
#  'slow muscle cell',
#  'small intestine goblet cell',
#  'smooth muscle cell',
#  'smooth muscle cell of large intestine',
#  'smooth muscle cell of small intestine',
#  'smooth muscle cell of sphincter of pupil',
#  'smooth muscle cell of the pulmonary artery',
#  'smooth muscle myoblast',
#  'sncg GABAergic cortical interneuron',
#  'sperm',
#  'sst GABAergic cortical interneuron',
#  'sst chodl GABAergic cortical interneuron',
#  'starburst amacrine cell',
#  'stem cell',
#  'stromal cell',
#  'stromal cell of endometrium',
#  'stromal cell of ovary',
#  'supporting cell',
#  'suprabasal keratinocyte',
#  'surface ectodermal cell',
#  'syncytiotrophoblast cell',
#  'tendon cell',
#  'thymocyte',
#  'tongue muscle cell',
#  'tracheal goblet cell',
#  'tracheobronchial goblet cell',
#  'tracheobronchial serous cell',
#  'tracheobronchial smooth muscle cell',
#  'transit amplifying cell',
#  'transit amplifying cell of colon',
#  'transit amplifying cell of small intestine',
#  'transitional stage B cell',
#  'trophoblast giant cell',
#  'tuft cell of colon',
#  'type B pancreatic cell',
#  'type EC enteroendocrine cell',
#  'type I NK T cell',
#  'type I pneumocyte',
#  'type II pneumocyte',
#  'type L enteroendocrine cell',
#  'unipolar brush cell',
#  'unknown',
#  'unswitched memory B cell',
#  'uterine smooth muscle cell',
#  'vascular associated smooth muscle cell',
#  'vascular leptomeningeal cell',
#  'vein endothelial cell',
#  'vip GABAergic cortical interneuron'}

# %%
# Function to check one unique donor_id and at least two distinct cell types
def filter_by_donor_and_celltype(df):
    return (df['donor_id'].nunique() == 1) and (df['cell_type'].nunique() >= 2)

# Apply group filtering by dataset_id
final_datasets = cell_metadata_filtered.groupby('dataset_id').filter(filter_by_donor_and_celltype)
# Out:
# /tmp/ipykernel_92863/3687241347.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   final_datasets = cell_metadata_filtered.groupby('dataset_id').filter(filter_by_donor_and_celltype)

# %%
set(final_datasets.donor_id.unique())
# Out:
# {'H11',
#  'H18.30.002',
#  'H19.30.001',
#  'H19.30.002',
#  'TSP12',
#  'TSP2',
#  'TSP4',
#  'healthy_6',
#  'manaab_H71',
#  'pooled'}

# %% [markdown]
# Extract only the cells from the latest 10x 3' v3 chromium assay

# %%
cell_metadata=cell_metadata[cell_metadata['assay']=="10x 3' v3"]

# %% [markdown]
# To avoid batch effect handlings, select cells from one dataset

# %% [markdown]
# Overview

# %%
ctb=pd.crosstab(cell_metadata['dataset_id'],cell_metadata['donor_id'])
mtd=cell_metadata.groupby(['dataset_id','donor_id']).count()
mtdsub=mtd[mtd['assay']>8000]
mtdsub=mtdsub[mtdsub['assay']<20000]
sel_dataset=[e[0] for e in mtdsub.index]
sel_donor=[e[1] for e in mtdsub.index]
cell_metadata=cell_metadata[cell_metadata['donor_id'].isin(sel_donor)]
cell_metadata=cell_metadata[cell_metadata['dataset_id'].isin(sel_dataset)]
# Out:
# /tmp/ipykernel_421026/420663332.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mtd=cell_metadata.groupby(['dataset_id','donor_id']).count()

# %%
len(cell_metadata['dataset_id'].unique())
# Out:
# 237

# %%
cell_metadata.shape
# Out:
# (20172405, 7)

# %%
ctct=pd.crosstab(cell_metadata['dataset_id'],cell_metadata['cell_type'])

# %%
ctct
# Out:
# cell_type                             B cell  Bergmann glial cell  \
# dataset_id
# 00476f9f-ebc1-4b72-b541-32f912ce36ea       0                    0
# 03c544fb-a103-4d18-9230-eae9cfee3af2                                   0
# ...                                                                  ...
# fbf173f9-f809-4d84-9b65-ae205d35b523                                   0
# fe1a73ab-a203-45fd-84e9-0f7fd19efcbd                                   0
# fe4b89d5-461e-440c-a5a8-621b37b122c0                                   0
# fe52003e-1460-4a65-a213-2bb1a508332f                                   0
# ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded                                   0
#
# [237 rows x 419 columns]

# %%
#We filter for datasets with at least two cell types
ctct=ctct[np.sum(ctct>10,axis=1)>2]
# and  maximum 30 cell types
ctct=ctct[np.sum(ctct>10,axis=1)<30]
# we get the metadata for this cells
cell_metadata=cell_metadata[cell_metadata['dataset_id'].isin(ctct.index)]

# %%
cell_metadata
# Out:
#               assay                                          cell_type  \
# 402735    10x 3' v3                                   retinal rod cell
# 402736    10x 3' v3                                   retinal rod cell
# 402737    10x 3' v3                                      amacrine cell
# 402738    10x 3' v3                                    macroglial cell
# 402739    10x 3' v3                             retinal bipolar neuron
# ...             ...                                                ...
# 74322505  10x 3' v3               pvalb GABAergic cortical interneuron
# 74322506  10x 3' v3                 vip GABAergic cortical interneuron
# 74322507  10x 3' v3  L2/3-6 intratelencephalic projecting glutamate...
# 74322508  10x 3' v3                   astrocyte of the cerebral cortex
# 74322509  10x 3' v3                 sst GABAergic cortical interneuron
#
#                                   tissue tissue_general    donor_id   disease  \
# 402735                      macula lutea            eye     donor_2    normal
# 402736                      macula lutea            eye     donor_2    normal
# 402737                      macula lutea            eye     donor_2    normal
# 402738                      macula lutea            eye     donor_2    normal
# 402739                      macula lutea            eye     donor_2    normal
# ...                                  ...            ...         ...       ...
# 74322505  dorsolateral prefrontal cortex          brain  H21.33.044  dementia
# 74322506  dorsolateral prefrontal cortex          brain  H20.33.018  dementia
# 74322507  dorsolateral prefrontal cortex          brain  H21.33.003    normal
# 74322508  dorsolateral prefrontal cortex          brain  H21.33.019    normal
# 74322509  dorsolateral prefrontal cortex          brain  H20.33.020  dementia
#
#                                     dataset_id
# 402735    856c1b98-5727-49da-bf0f-151bdb8cb056
# 402736    856c1b98-5727-49da-bf0f-151bdb8cb056
# 402737    856c1b98-5727-49da-bf0f-151bdb8cb056
# 402738    856c1b98-5727-49da-bf0f-151bdb8cb056
# 402739    856c1b98-5727-49da-bf0f-151bdb8cb056
# ...                                        ...
# 74322505  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322506  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322507  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322508  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322509  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
#
# [15818764 rows x 7 columns]

# %%
cell_metadata.shape
# Out:
# (15818764, 7)

# %% [markdown]
# We now aim to select only one of the donors of the experiment with higher number of cells

# %%
dataset_id_used=[]
dataset_id_selected=[]
donor_id_selected=[]

ctb=pd.crosstab(cell_metadata['dataset_id'],cell_metadata['donor_id'])
mtd=cell_metadata.groupby(['dataset_id','donor_id']).count()

for ind in mtd.index:
    if ind[0] not in dataset_id_used:
        dataset_id_used.append(ind[0])
        dataset_id_selected.append(ind[0])
        donor_id_selected.append(ind[1])

datasets_to_use=pd.DataFrame([dataset_id_selected,donor_id_selected],index=['dataset_id','donor_id']).transpose()
# Out:
# /tmp/ipykernel_421026/1514112350.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mtd=cell_metadata.groupby(['dataset_id','donor_id']).count()

# %%
datasets_to_use
# Out:
#                                dataset_id donor_id
# 0    0041b9c3-6a49-4bf7-8514-9bc7190067a7     #105
# 1    00476f9f-ebc1-4b72-b541-32f912ce36ea     #105
# 2    00e5dedd-b9b7-43be-8c28-b0e5c6414a62     #105
# 3    00ff600e-6e2e-4d76-846f-0eec4f0ae417     #105
# 4    01209dce-3575-4bed-b1df-129f57fbc031     #105
# ..                                    ...      ...
# 673  fe1a73ab-a203-45fd-84e9-0f7fd19efcbd     #105
# 674  fe4b89d5-461e-440c-a5a8-621b37b122c0     #105
# 675  fe52003e-1460-4a65-a213-2bb1a508332f     #105
# 676  ff45e623-7f5f-46e3-b47d-56be0341f66b     #105
# 677  ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded     #105
#
# [678 rows x 2 columns]

# %%
cell_metadata['dataset_id']
# Out:
# 402735      856c1b98-5727-49da-bf0f-151bdb8cb056
# 402736      856c1b98-5727-49da-bf0f-151bdb8cb056
# 402737      856c1b98-5727-49da-bf0f-151bdb8cb056
# 402738      856c1b98-5727-49da-bf0f-151bdb8cb056
# 402739      856c1b98-5727-49da-bf0f-151bdb8cb056
#                             ...
# 74322505    6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322506    6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322507    6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322508    6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# 74322509    6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
# Name: dataset_id, Length: 15818764, dtype: category
# Categories (678, object): ['0041b9c3-6a49-4bf7-8514-9bc7190067a7', '00476f9f-ebc1-4b72-b541-32f912ce36ea', '00e5dedd-b9b7-43be-8c28-b0e5c6414a62', '00ff600e-6e2e-4d76-846f-0eec4f0ae417', ..., 'fe4b89d5-461e-440c-a5a8-621b37b122c0', 'fe52003e-1460-4a65-a213-2bb1a508332f', 'ff45e623-7f5f-46e3-b47d-56be0341f66b', 'ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded']

# %%
len(datasets_to_use['dataset_id'].unique())
# Out:
# 678

# %%
cell_metadata[cell_metadata['donor_id'] == '#105']
# Out:
#               assay                cell_type  \
# 14121878  10x 3' v3  cerebellar granule cell
# 14121879  10x 3' v3  cerebellar granule cell
# 14121880  10x 3' v3  cerebellar granule cell
# 14121881  10x 3' v3      Bergmann glial cell
# 14121882  10x 3' v3  cerebellar granule cell
# ...             ...                      ...
# 14163130  10x 3' v3          oligodendrocyte
# 14163131  10x 3' v3                  unknown
# 14163132  10x 3' v3          macroglial cell
# 14163133  10x 3' v3          macroglial cell
# 14163134  10x 3' v3          macroglial cell
#
#                                                 tissue tissue_general  \
# 14121878  hemisphere part of cerebellar posterior lobe          brain
# 14121879  hemisphere part of cerebellar posterior lobe          brain
# 14121880  hemisphere part of cerebellar posterior lobe          brain
# 14121881  hemisphere part of cerebellar posterior lobe          brain
# 14121882  hemisphere part of cerebellar posterior lobe          brain
# ...                                                ...            ...
# 14163130  hemisphere part of cerebellar posterior lobe          brain
# 14163131  hemisphere part of cerebellar posterior lobe          brain
# 14163132  hemisphere part of cerebellar posterior lobe          brain
# 14163133  hemisphere part of cerebellar posterior lobe          brain
# 14163134  hemisphere part of cerebellar posterior lobe          brain
#
#          donor_id disease                            dataset_id
# 14121878     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14121879     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14121880     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14121881     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14121882     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# ...           ...     ...                                   ...
# 14163130     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14163131     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14163132     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14163133     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
# 14163134     #105  normal  bab7432a-5cfe-45ea-928c-422d03c45cdd
#
# [15580 rows x 7 columns]

# %%
for cell_type in cell_metadata[cell_metadata['donor_id'] == '#105']['cell_type'].unique():
    print(cell_type)
    print(cell_metadata[cell_metadata['cell_type'] == cell_type].shape[0])
# Out:
# cerebellar granule cell
# 31221
# Bergmann glial cell
# 9082
# interneuron
# 903
# unknown
# 117286
# oligodendrocyte
# 802360
# immature astrocyte
# 2
# differentiation-committed oligodendrocyte precursor
# 571
# meningeal macrophage
# 20
# brain vascular cell
# 4490
# T cell
# 92838
# macroglial cell
# 5887
# leukocyte
# 31793
# microglial cell
# 165816

# %%
'oligodendrocyte'
'T cell'

# %%
import cellxgene_census

with cellxgene_census.open_soma() as census:
    adata = cellxgene_census.get_anndata(
        census = census,
        organism = "Homo sapiens",
        var_value_filter = "feature_id in ['ENSG00000161798', 'ENSG00000188229']",
        obs_value_filter = "donor_id == '#105' and dataset_id == 'bab7432a-5cfe-45ea-928c-422d03c45cdd' and cell_type in ['T cell', 'oligodendrocyte']",
        column_names = {"obs": ["assay", "cell_type", "tissue", "tissue_general", "disease"]},
    )

    print(adata)
# Out:
# The "stable" release is currently 2024-07-01. Specify 'census_version="2024-07-01"' in future calls to open_soma() to ensure data consistency.
# /tmp/ipykernel_421026/880625280.py:4: FutureWarning: The argument `column_names` is deprecated and will be removed in a future release. Please use `obs_column_names` and `var_column_names` instead.
#   adata = cellxgene_census.get_anndata(
# AnnData object with n_obs × n_vars = 357 × 2
#     obs: 'assay', 'cell_type', 'tissue', 'tissue_general', 'disease', 'donor_id', 'dataset_id'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
adata.obs.cell_type.unique()
# Out:
# ['oligodendrocyte', 'T cell']
# Categories (698, object): ['A2 amacrine cell', 'B cell', 'B-1 B cell', 'B-1a B cell', ..., 'vein endothelial cell', 'ventricular cardiac muscle cell', 'vip GABAergic cortical interneuron', 'visceromotor neuron']

# %%
adata.var
# Out:
#    soma_joinid       feature_id feature_name  feature_length       nnz  \
# 0        10507  ENSG00000161798         AQP5            1884   1226640
# 1        16091  ENSG00000188229       TUBB4B            2037  26463689
#
#    n_measured_obs
# 0        68915280
# 1        73806975

# %%
i

# %%
census = cellxgene_census.get_census_version("latest")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 census = cellxgene_census.get_census_version("latest")
#
# AttributeError: module 'cellxgene_census' has no attribute 'get_census_version'

# %%
census.metadata()  # adjust based on actual dataset fetching method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 census.metadata()
#
# TypeError: 'MetadataWrapper' object is not callable

# %%
dir(census)
# Out:
# ['_MutableMapping__marker',
#  '__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__del__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_new_element',
#  '_add_new_ndarray',
#  '_check_allows_child',
#  '_check_open_read',
#  '_close_stack',
#  '_contents',
#  '_contents_lines',
#  '_del_element',
#  '_handle',
#  '_mutated_keys',
#  '_my_repr',
#  '_new_child_uri',
#  '_set_element',
#  '_subclass_constrained_soma_types',
#  '_wrapper_type',
#  'add_new_collection',
#  'add_new_dataframe',
#  'add_new_dense_ndarray',
#  'add_new_sparse_ndarray',
#  'clear',
#  'close',
#  'closed',
#  'context',
#  'create',
#  'exists',
#  'get',
#  'items',
#  'keys',
#  'members',
#  'metadata',
#  'mode',
#  'open',
#  'pop',
#  'popitem',
#  'reopen',
#  'set',
#  'setdefault',
#  'soma_type',
#  'tiledb_timestamp',
#  'tiledb_timestamp_ms',
#  'update',
#  'uri',
#  'values',
#  'verify_open_for_writing']

# %%
# Filter for specific criteria
filtered_datasets = datasets[
    (datasets['assay'] == 'v3') &
    (datasets['disease'] == 'normal')
]

# Function to check one unique donor_id and at least two distinct cell types
def filter_by_donor_and_celltype(df):
    return (df['donor_id'].nunique() == 1) and (df['cell_type'].nunique() >= 2)

# Apply group filtering by dataset_id
final_datasets = filtered_datasets.groupby('dataset_id').filter(filter_by_donor_and_celltype)

# Display the result
print(final_datasets[['dataset_id', 'donor_id', 'cell_type']])

# %%
census = cellxgene_census.open_soma()
# Out:
# The "stable" release is currently 2024-07-01. Specify 'census_version="2024-07-01"' in future calls to open_soma() to ensure data consistency.

# %%
dir(cellxgene_census.open_soma)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__']
